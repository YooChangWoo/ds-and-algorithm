# %%
### 코딩테스트

# %% [markdown]
# 1. P217 스택 Code06-08.py의 선언된 함수를 자신이 좋아하는 형태의 이름으로 바꾸어 완성하시오. 실행결과를 P219와 다르게 테스트 해보세요.
# 예) isStackFull -> 스택풀확인 / amIfull 등...

# %%
def stackfull():
    global SIZE, name, top
    if(top >= SIZE-1):
        return True
    else:
        return False
    
def stackempty():
    global SIZE, name, top
    if (top==-1):
        return True
    else:
        return False
    
def push(data):
    global SIZE, name, top
    if(stackfull()):
        print('상자가 꽉 찼습니다')
        return
    top +=1
    name[top] = data

def pop():
    global SIZE, name, top
    if(stackempty()):
        print('상자가 피었습니다.')
        return None
    data = name[top]
    name[top] = None
    top -= 1
    return data

def peek():
    global SIZE, name, top
    if(stackempty()):
        print('상자가 비었습니다.')
        return None
    return name[top]

SIZE = int(input('상자 갯수를 입력하세요'))
name = [None for _ in range(SIZE)]
top =-1

if __name__=='__main__':
    select = input('삽입(a)/ 추출(b)/ 확인(o)/ 종료(x) 중 하나를 선택하세요 ->')

    while(select != 'x' and select!= 'x'):
        if select == 'a' or select =='a':
            data = input('입력할 데이터 ==>')
            push(data)
            print('상자 상태 : ', name)
        elif select == 'b' or select =='B':
            data=pop()
            print('추출된 데이터 ->', data)
            print('상자 상태 : ', name)
        else:
            print('입력이 잘못되었습니다.')

        select = input('삽입(a)/ 추출(b)/ 확인(o)/ 종료(x) 중 하나를 선택하세요 ->')
        
    print('프로그램 종료')
# Out:
# 상자 상태 :  ['담배', None, None, None, None]
# 상자 상태 :  ['담배', '술', None, None, None]
# 상자 상태 :  ['담배', '술', '라이터', None, None]
# 상자 상태 :  ['담배', '술', '라이터', '로또', None]
# 입력이 잘못되었습니다.
# 추출된 데이터 -> 로또
# 상자 상태 :  ['담배', '술', '라이터', None, None]
# 추출된 데이터 -> 라이터
# 상자 상태 :  ['담배', '술', None, None, None]
# 추출된 데이터 -> 술
# 상자 상태 :  ['담배', None, None, None, None]
# 추출된 데이터 -> 담배
# 상자 상태 :  [None, None, None, None, None]
# 프로그램 종료

# %% [markdown]
# 2. P269 유명 맛집 대기줄 구현하기 문제를 while True:문을 사용하여 동적으로 입력을 받는 프로그램으로 변경작성하시오.

# %%
def queuefull():
    global SIZE, queue, front, rear
    if (rear == SIZE-1):
        return True
    else:
        return False
    
def queueempty():
    global SIZE, queue, front, rear
    if (front == rear):
        return True
    else:
        return False
    
def enqueue(data):
    global SIZE, queue, front, rear
    if (queuefull()):
        print('큐가 꽉 찼습니다.')
        return
    rear += 1
    queue[rear] = data

def dequeue():
    global SIZE, queue, front, rear
    if (queueempty()):
        print('큐가 비었습니다.')
        return None
    front += 1
    data = queue[front]
    queue[front] = None

    for i in range(front+1, rear+1):
        queue[i-1] = queue[i]
        queue[i] = None
    front = -1
    rear -= 1

    return data

def peek():
    global SIZE, queue, front, rear
    if (queueempty()):
        print('큐가 비었습니다.')
        return None
    return queue[front+1]

SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

if __name__ == '__main__':
    enqueue('창우')
    enqueue('솔비')
    enqueue('정자')
    enqueue('창근')
    enqueue('승우')
    print('대기줄 상태:', queue)

    for _ in range(rear+1):
        print(dequeue(),'님 식당에 들어갑니다.')
        print('대기줄 상태:', queue)

    print('식당 영업 종료!')

# %%
### while True 문
if __name__ == '__main__':
    while True:
        enqueue('창우')
        enqueue('솔비')
        enqueue('정자')
        enqueue('창근')
        enqueue('승우')
        print('대기줄 상태:', queue)

        for _ in range(rear + 1):
            print(dequeue(), '님 식당에 들어갑니다.')
            print('대기줄 상태:', queue)

        print('식당 영업 종료!')

# %% [markdown]
# 3. P309 편의점 판매된 물건 목록 출력하기 문제 역시 while True: 문으로 동적으로 입력받는 프로그램으로 변경하시오.

# %%
import random
## 함수 선언 부분##
class TreeNode():
    def __init__(self) -> None:
        self.left = None
        self.data = None
        self.right = None
def isQueueFull():
    global SIZE, queue, front, rear
    if(rear == SIZE-1):
        return True
    else:
        return False
    
def isQueueEmpty():
    global SIZE, queue, front, rear
    if(front == rear):
        return True
    else:
        return False
    
def enQueue(data):
    global SIZE, queue, front, rear
    if (isQueueFull()):
        return
    rear += 1
    queue[rear] = data

def deQueue():
    global SIZE, queue, front, rear
    if (isQueueEmpty()):
        print("목록이 비었습니다.")
        return None
    front += 1
    data = queue[front]
    queue[front] = None

    for i in range(front+1, rear+1):
        queue[i-1] = queue[i]
        queue[i] = None
    front = -1
    rear -= 1

    return data

## 전역 변수 선언 부분 ##
memory = []
root = None
dataAry = []
while True:
        select = input('삽입(i), 종료(x) > ')

        if select.lower() == 'i':
            dataAry.append(input('입력 데이터 > '))
            enQueue(dataAry)
            print(f'물품 목록 : {dataAry}')
        elif select.lower() == 'x':
            break
        else:
            continue

sellAry = [random.choice(dataAry) for _ in range(20)]

print('오늘 판매된 물건(중복0) --> ', sellAry)

## 메인 코드 부분 ##
node = TreeNode()
node.data = sellAry[0]
root = node
memory.append(node)

for name in sellAry[1:] :

    node = TreeNode()
    node.data = name

    current = root
    while True:
        if name == current.data:
            break
        if name < current.data:
            if current.left == None:
                current.left = node
                memory.append(node)
                break
            current = current.left
        else:
            if current.right == None:
                current.right = node
                memory.append(node)
                break
            current = current.right

print('이진 탐색 트리 구성 완료!')

def preorder(node):
    if node == None:
        return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

print('오늘 판매된 종류(중복X) --> ', end=' ')
preorder(root)
# Out:
# 물품 목록 : ['물']
# 물품 목록 : ['물', '담배']
# 물품 목록 : ['물', '담배', '맥주']
# 오늘 판매된 물건(중복0) -->  ['맥주', '담배', '물', '담배', '맥주', '물', '맥주', '맥주', '물', '맥주', '맥주', '담배', '맥주', '물', '담배', '맥주', '맥주', '맥주', '맥주', '맥주']
# 이진 탐색 트리 구성 완료!
# 오늘 판매된 종류(중복X) -->  맥주 담배 물

# %%
import random

class TreeNode:
    def __init__(self, data=None):
        self.data = data
        self.left = None
        self.right = None

# 전역 변수 및 초기화
memory = []
root = None
dataAry = []

while True:
    select = input('삽입(i), 종료(x): ')

    if select.lower() == 'i':
        data = input('입력 데이터: ')
        dataAry.append(data)
        print(f'물품 목록: {dataAry}')
    elif select.lower() == 'x':
        break
    else:
        print('올바른 명령을 입력하세요.')

sellAry = [random.choice(dataAry) for _ in range(20)]
print('오늘 판매된 물건(중복0):', sellAry)

# 이진 탐색 트리 구성
node = TreeNode(sellAry[0])
root = node
memory.append(node)

for name in sellAry[1:]:
    node = TreeNode(name)
    current = root
    while True:
        if name == current.data:
            break
        if name < current.data:
            if current.left is None:
                current.left = node
                memory.append(node)
                break
            current = current.left
        else:
            if current.right is None:
                current.right = node
                memory.append(node)
                break
            current = current.right

print('이진 탐색 트리 구성 완료!')

# 전위 순회 함수 정의
def preorder(node):
    if node is None:
        return
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

print('오늘 판매된 종류(중복X):', end=' ')
preorder(root)
# Out:
# 올바른 명령을 입력하세요.
# 올바른 명령을 입력하세요.
# 물품 목록: ['물']
# 물품 목록: ['물', '과자']
# 물품 목록: ['물', '과자', '술']
# 물품 목록: ['물', '과자', '술', '물']
# 오늘 판매된 물건(중복0): ['과자', '술', '물', '물', '과자', '물', '물', '물', '물', '물', '술', '과자', '물', '과자', '물', '술', '물', '과자', '과자', '술']
# 이진 탐색 트리 구성 완료!
# 오늘 판매된 종류(중복X): 과자 술 물
